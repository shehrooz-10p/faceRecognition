('subject13_137_11zon.jpg','Manny'),
('subject13_138_11zon.jpg','Manny'),
('subject13_139_11zon.jpg','Manny'),
('subject13_140_11zon.jpg','Manny'),
('subject13_141_11zon.jpg','Manny'),
('subject13_142_11zon.jpg','Manny'),
('subject13_143_11zon.jpg','Manny'),
('subject14_144_11zon.jpg','Ned'),
('subject14_145_11zon.jpg','Ned'),
('subject14_146_11zon.jpg','Ned'),
('subject14_147_11zon.jpg','Ned'),
('subject14_148_11zon.jpg','Ned'),
('subject14_149_11zon.jpg','Ned'),
('subject14_150_11zon.jpg','Ned'),
('subject14_151_11zon.jpg','Ned'),
('subject14_152_11zon.jpg','Ned'),
('subject14_153_11zon.jpg','Ned'),
('subject14_154_11zon.jpg','Ned'),
('subject15_155_11zon.jpg','oxam'),
('subject15_156_11zon.jpg','oxam'),
('subject15_157_11zon.jpg','oxam'),
('subject15_158_11zon.jpg','oxam'),
('subject15_159_11zon.jpg','oxam'),
('subject15_160_11zon.jpg','oxam'),
('subject15_161_11zon.jpg','oxam'),
('subject15_162_11zon.jpg','oxam'),
('subject15_163_11zon.jpg','oxam'),
('subject15_164_11zon.jpg','oxam'),
('subject15_165_11zon.jpg','oxam'),

      ]

# %%
for image in imagesTrain[0::11]:
    my_image = Image.open(image[0])
    title_font = ImageFont.truetype('PlayfairDisplay-Regular.ttf', 30)
    title_text = image[1]
    image_editable = ImageDraw.Draw(my_image)
    image_editable.text((15,15), title_text, (255, 0, 255), font=title_font)
    display(my_image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F98A250>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F970A30>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F98A250>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F970F70>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F98A250>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F970970>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F98A250>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F970DC0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F98A250>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F970190>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F98A250>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F970430>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F98A250>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F970EB0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F98A250>

# %%
for image in imagesTrain[0:11]:
    my_image = Image.open(image[0])
    title_font = ImageFont.truetype('PlayfairDisplay-Regular.ttf', 30)
    title_text = image[1]
    image_editable = ImageDraw.Draw(my_image)
    image_editable.text((15,15), title_text, (255, 0, 255), font=title_font)
    display(my_image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F98A310>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F970C10>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F98AFA0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F98A4C0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F98AFA0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F98A4C0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F98AFA0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F98A4C0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F9702B0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F98A4C0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F970E80>

# %%
# Iterate through list to upload objects to S3   
for image in imagesTrain:
    file = open(image[0],'rb')
    print('Processing - Done  ::  'image[0])
    object = s3.Object('face-matchings','index/'+ image[0])
    ret = object.put(Body=file,
                    Metadata={'FullName':image[1]}
                    )
# Out:
# subject02_12_11zon.jpg
# subject03_23_11zon.jpg
# subject04_34_11zon.jpg
# subject05_45_11zon.jpg
# subject06_56_11zon.jpg
# subject07_67_11zon.jpg
# subject08_78_11zon.jpg
# subject09_89_11zon.jpg
# subject10_100_11zon.jpg
# subject11_111_11zon.jpg
# subject12_122_11zon.jpg
# subject13_133_11zon.jpg
# subject14_144_11zon.jpg
# subject15_155_11zon.jpg

# %%
imagesTest=[('subject01_11_11zon.jpg','Alex'),
           ('subject02_22_11zon.jpg','Bob'),
            ('subject03_33_11zon.jpg','Charlie'),
            ('subject04_44_11zon.jpg','Denis'),
            ('subject05_55_11zon.jpg','Ellie'),
            ('subject06_66_11zon.jpg','Ferry'),
            ('subject07_77_11zon.jpg','Garry'),
            ('subject08_88_11zon.jpg','Harry'),
            ('subject09_99_11zon.jpg','Irina'),
            ('subject10_110_11zon.jpg','Jerry'),
            ('subject11_121_11zon.jpg','Kim'),
            ('subject12_132_11zon.jpg','leo'),
            ('subject13_143_11zon.jpg','Manny'),
            ('subject14_154_11zon.jpg','Ned'),
            ('subject15_165_11zon.jpg','oxam')]

# %%
for imageTest in imagesTest:
    print('####################################################')
    personNameConfidences = {}
    print('---------------------------------------------')
    print('Actual Image of the Person :: ' + imageTest[1] )
    print('---------------------------------------------')
    imageLoaded = Image.open(imageTest[0])
    display(imageLoaded)
    stream = io.BytesIO()
    imageLoaded.save(stream,format="JPEG")
    image_binary = stream.getvalue()

    response = rekognition.search_faces_by_image(
            CollectionId='face-matching',
            Image={'Bytes':image_binary}                                       
            )
    
    for match in response['FaceMatches']:
        facePrintID = match['Face']['FaceId']
        confidence = round(match['Face']['Confidence'], 5)
        print ('FacePrintID: ',facePrintID,'  ::  ' ,'Confidence: ' ,confidence)

        face = dynamodb.get_item(
            TableName='face-matching',  
            Key={'RekognitionId': {'S': match['Face']['FaceId']}}
            )
        
        if 'Item' in face:
            personName = face['Item']['FullName']['S']
            if personName in personNameConfidences.keys():
                personNameConfidences[personName].append(confidence)
            else:
                personNameConfidences[personName] = [confidence]
                
            print ('Identified Person :: ',personName)
            print('---')
        else:
            print ('no match found in person lookup')
    print('---------------------')        
    print(personNameConfidences)
    print('---------------------') 
    #Fuzzy Logic
    
    identifiedPersonConfidence = {}
    for personName in personNameConfidences.keys():
        averageConfidence = round(sum(personNameConfidences[personName]) / len(personNameConfidences[personName]), 5) 
        identifiedPersonConfidence[personName]=averageConfidence
        print( 'Identified Person : ',personName, '  ::  ', 'Confidence : ', averageConfidence)
        print('---------------------')

    predictedPerson = ''
    maxConfidence = 0
    for identifiedPerson in identifiedPersonConfidence.keys():
        if identifiedPersonConfidence[identifiedPerson] > maxConfidence:
            maxConfidence = identifiedPersonConfidence[identifiedPerson]
            predictedPerson = identifiedPerson
    # Display Image        
    title_font = ImageFont.truetype('PlayfairDisplay-Regular.ttf', 30)
    confidence_font = ImageFont.truetype('PlayfairDisplay-Regular.ttf', 15) 
    image_editable = ImageDraw.Draw(imageLoaded)
    image_editable.text((15,15), predictedPerson, (0, 0, 0), font=title_font)
    image_editable.text((15,50), str(maxConfidence), (0, 0, 0), font=confidence_font)
    display(imageLoaded)
    print('####################################################')
    personNameConfidences.clear()
    identifiedPersonConfidence.clear()
# Out:
# ####################################################
# ---------------------------------------------
# Actual Image of the Person :: Alex
# ---------------------------------------------
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F8A7190>
# FacePrintID:  60395350-e93d-4599-99e4-4f3fe76e4360   ::   Confidence:  99.99979
# Identified Person ::  Alex
# ---
# FacePrintID:  963e0833-4500-410f-b2e7-1cc30eeea6ae   ::   Confidence:  99.99979
# Identified Person ::  Alex
# ---
# FacePrintID:  fa48622f-97bb-4604-b6bc-fb384ba48e30   ::   Confidence:  99.9997
# Identified Person ::  Alex
# ---
# FacePrintID:  1ae87c03-a6a9-450d-b5ee-ddb289d28934   ::   Confidence:  99.9999
# Identified Person ::  Alex
# ---
# FacePrintID:  d5b76127-fcca-400b-a0ab-c19280cf12e1   ::   Confidence:  99.9997
# Identified Person ::  Alex
# ---
# FacePrintID:  0ab668d2-bf2f-4d86-92f6-07a96f7b5357   ::   Confidence:  99.99979
# Identified Person ::  Alex
# ---
# FacePrintID:  65f2f018-71fb-4524-8013-8d8d9acfd6de   ::   Confidence:  99.9999
# Identified Person ::  Alex
# ---
# FacePrintID:  682690f0-70c5-47aa-b095-136b06a82169   ::   Confidence:  99.9996
# Identified Person ::  Alex
# ---
# FacePrintID:  fc8f87f5-c701-464b-8a56-2d075b2e9718   ::   Confidence:  99.99979
# Identified Person ::  Alex
# ---
# FacePrintID:  e68acd86-d664-48c7-8567-cfb8ec16178c   ::   Confidence:  99.99979
# Identified Person ::  Alex
# ---
# FacePrintID:  f0913e35-1288-4551-b56b-23fc5f2c2574   ::   Confidence:  99.99979
# Identified Person ::  Alex
# ---
# ---------------------
# {'Alex': [99.99979, 99.99979, 99.9997, 99.9999, 99.9997, 99.99979, 99.9999, 99.9996, 99.99979, 99.99979, 99.99979]}
# ---------------------
# Identified Person :  Alex   ::   Confidence :  99.99978
# ---------------------
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F8A7190>
# ####################################################
# ####################################################
# ---------------------------------------------
# Actual Image of the Person :: Bob
# ---------------------------------------------
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F940430>
# FacePrintID:  ea0c2348-c3a7-4133-a70f-793f3c02dd56   ::   Confidence:  99.9999
# Identified Person ::  Bob
# ---
# FacePrintID:  6d18164b-702a-4107-96e4-ac9cb19a4745   ::   Confidence:  99.9995
# Identified Person ::  Bob
# ---
# FacePrintID:  65927b03-3093-4537-bce4-551b63762416   ::   Confidence:  99.9995
# Identified Person ::  Bob
# ---
# FacePrintID:  3bdabb0c-70f5-47ae-a6b3-1d8503744caf   ::   Confidence:  99.9996
# Identified Person ::  Bob
# ---
# FacePrintID:  d4876ee5-1160-46c0-b8d8-583076506e75   ::   Confidence:  99.9996
# Identified Person ::  Bob
# ---
# FacePrintID:  dc7ed17b-80a6-4277-8c18-78f4a751cd2c   ::   Confidence:  99.9994
# Identified Person ::  Bob
# ---
# FacePrintID:  1bb71f9f-eee2-49ae-97b9-ecb16f6f3033   ::   Confidence:  99.99931
# Identified Person ::  Bob
# ---
# FacePrintID:  42df2edc-2007-4d2c-9327-3a8ef0e6e4cc   ::   Confidence:  99.9995
# Identified Person ::  Bob
# ---
# FacePrintID:  6ca73f3d-5404-465a-8114-c77617014642   ::   Confidence:  99.9995
# Identified Person ::  Bob
# ---
# FacePrintID:  eb175eab-d430-4e56-a61b-1686532384c6   ::   Confidence:  99.9994
# Identified Person ::  Bob
# ---
# ---------------------
# {'Bob': [99.9999, 99.9995, 99.9995, 99.9996, 99.9996, 99.9994, 99.99931, 99.9995, 99.9995, 99.9994]}
# ---------------------
# Identified Person :  Bob   ::   Confidence :  99.99952
# ---------------------
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F940430>
# ####################################################
# ####################################################
# ---------------------------------------------
# Actual Image of the Person :: Charlie
# ---------------------------------------------
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F96B4F0>
# FacePrintID:  352fea37-b91d-4edf-b201-dc148f9cfe45   ::   Confidence:  99.99979
# Identified Person ::  Charlie
# ---
# FacePrintID:  6d6c283f-830e-4910-8ad4-0e5cb2ae4ca2   ::   Confidence:  99.99979
# Identified Person ::  Charlie
# ---
# FacePrintID:  2652d378-abe1-44ed-a1c5-8222acd47642   ::   Confidence:  99.99979
# Identified Person ::  Charlie
# ---
# FacePrintID:  9a04a2b4-7110-474d-b213-e26a823e6d98   ::   Confidence:  99.9994
# Identified Person ::  Charlie
# ---
# FacePrintID:  c75fe011-31a2-48d0-b95a-564087f14e39   ::   Confidence:  99.9999
# Identified Person ::  Charlie
# ---
# FacePrintID:  c6639b1c-23fb-4aff-a10b-b6887a6c8c7f   ::   Confidence:  99.9997
# Identified Person ::  Charlie
# ---
# FacePrintID:  3a299153-0553-488d-81d5-798cebe7e8a6   ::   Confidence:  99.99979
# Identified Person ::  Charlie
# ---
# FacePrintID:  4c50b1e0-f63f-476c-b5f8-f46f307c2fb3   ::   Confidence:  99.9997
# Identified Person ::  Charlie
# ---
# FacePrintID:  266b607d-6661-44a1-ac8b-9af0646607b2   ::   Confidence:  99.9997
# Identified Person ::  Charlie
# ---
# FacePrintID:  235147ac-ea8c-49f2-a8ef-6452f81adf37   ::   Confidence:  99.9994
# Identified Person ::  Charlie
# ---
# ---------------------
# {'Charlie': [99.99979, 99.99979, 99.99979, 99.9994, 99.9999, 99.9997, 99.99979, 99.9997, 99.9997, 99.9994]}
# ---------------------
# Identified Person :  Charlie   ::   Confidence :  99.9997
# ---------------------
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F96B4F0>
# ####################################################
# ####################################################
# ---------------------------------------------
# Actual Image of the Person :: Denis
# ---------------------------------------------
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F965400>
# FacePrintID:  3f370082-452d-4b7d-b2c3-e7dbee3a9594   ::   Confidence:  99.99979
# Identified Person ::  Denis
# ---
# FacePrintID:  eefd4768-b969-4858-8f62-3b8e75849a0b   ::   Confidence:  99.99979
# Identified Person ::  Denis
# ---
# FacePrintID:  66bb0def-d0ed-41ee-9060-19e61615c89f   ::   Confidence:  99.99979
# Identified Person ::  Denis
# ---
# FacePrintID:  e899e969-fb5f-4120-8ba0-a12447f335ef   ::   Confidence:  99.9999
# Identified Person ::  Denis
# ---
# FacePrintID:  8fa85aa4-7e76-4bbe-b420-019373a2caab   ::   Confidence:  99.9999
# Identified Person ::  Denis
# ---
# FacePrintID:  1ddac98a-1175-461f-8299-fdb0e7d42d2d   ::   Confidence:  99.9999
# Identified Person ::  Denis
# ---
# FacePrintID:  48c452e5-ae16-4a6f-a56c-725dea7a2fb0   ::   Confidence:  99.9999
# Identified Person ::  Denis
# ---
# FacePrintID:  179b5360-223e-44fb-b4f6-da514679d032   ::   Confidence:  99.9997
# Identified Person ::  Denis
# ---
# FacePrintID:  5cc00c00-8c31-4154-b50f-941859efcdee   ::   Confidence:  99.99979
# Identified Person ::  Denis
# ---
# FacePrintID:  7ba0dd85-2bab-4684-abad-9be48ddcdedc   ::   Confidence:  99.99979
# Identified Person ::  Denis
# ---
# ---------------------
# {'Denis': [99.99979, 99.99979, 99.99979, 99.9999, 99.9999, 99.9999, 99.9999, 99.9997, 99.99979, 99.99979]}
# ---------------------
# Identified Person :  Denis   ::   Confidence :  99.99983
# ---------------------
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F965400>
# ####################################################
# ####################################################
# ---------------------------------------------
# Actual Image of the Person :: Ellie
# ---------------------------------------------
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923
# FacePrintID:  2e0c3f33-8c0e-4abf-bb50-3c44ba0b7728   ::   Confidence:  99.9995
# Identified Person ::  Harry
# ---
# FacePrintID:  c928770f-5314-4daf-8ed6-69d0e30a4446   ::   Confidence:  99.9997
# Identified Person ::  Harry
# ---
# ---------------------
# {'Harry': [99.9995, 99.9995, 99.9997, 99.9995, 99.99979, 99.9997, 99.9996, 99.999, 99.9995, 99.9997]}
# ---------------------
# Identified Person :  Harry   ::   Confidence :  99.99955
# ---------------------
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F97D2E0>
# ####################################################
# ####################################################
# ---------------------------------------------
# Actual Image of the Person :: Irina
# ---------------------------------------------
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F5C0910>
# FacePrintID:  ef3a7dcf-a01b-4878-8c50-85113e88d094   ::   Confidence:  99.99979
# Identified Person ::  Irina
# ---
# FacePrintID:  4744d006-ff03-405b-9e58-ce5d07973965   ::   Confidence:  99.9997
# Identified Person ::  Irina
# ---
# FacePrintID:  791172ed-9ac0-4815-b05d-cb2758ef7d01   ::   Confidence:  99.9997
# Identified Person ::  Irina
# ---
# FacePrintID:  6213d771-2f32-4bf7-b64e-27354a16fa0d   ::   Confidence:  99.9995
# Identified Person ::  Irina
# ---
# FacePrintID:  c4b9697a-d271-4728-9794-b3f1c8c81353   ::   Confidence:  99.99931
# Identified Person ::  Irina
# ---
# FacePrintID:  1548f3de-be00-4733-9b33-c15bac379e77   ::   Confidence:  99.9995
# Identified Person ::  Irina
# ---
# FacePrintID:  5e380282-f3df-4a92-bfe8-ca0021d66444   ::   Confidence:  99.9995
# Identified Person ::  Irina
# ---
# FacePrintID:  f830867e-917d-4177-b8b4-39438799fd0b   ::   Confidence:  99.99979
# Identified Person ::  Irina
# ---
# FacePrintID:  8db90962-665a-4851-845e-428a3abc531e   ::   Confidence:  99.9995
# Identified Person ::  Irina
# ---
# FacePrintID:  8622c674-870d-44d4-9b1b-a6906cecae64   ::   Confidence:  99.9997
# Identified Person ::  Irina
# ---
# ---------------------
# {'Irina': [99.99979, 99.9997, 99.9997, 99.9995, 99.99931, 99.9995, 99.9995, 99.99979, 99.9995, 99.9997]}
# ---------------------
# Identified Person :  Irina   ::   Confidence :  99.9996
# ---------------------
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F5C0910>
# ####################################################
# ####################################################
# ---------------------------------------------
# Actual Image of the Person :: Jerry
# ---------------------------------------------
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F940AF0>
# FacePrintID:  26b85cdc-6c9c-4fb5-ae93-a14d5db507e5   ::   Confidence:  99.99979
# Identified Person ::  Jerry
# ---
# FacePrintID:  101d4b89-65d4-468c-89b3-722d7d1fdead   ::   Confidence:  99.99979
# Identified Person ::  Jerry
# ---
# FacePrintID:  7d13f90a-b687-46f7-89b2-6d8fffc03691   ::   Confidence:  99.9996
# Identified Person ::  Jerry
# ---
# FacePrintID:  0f6f9f39-eb26-4301-bfbc-b8f3f8c0995e   ::   Confidence:  99.9997
# Identified Person ::  Jerry
# ---
# FacePrintID:  eca44b5f-da6c-47f9-bfed-4c408d4872c7   ::   Confidence:  99.9996
# Identified Person ::  Jerry
# ---
# FacePrintID:  d5ea663c-31ca-42f7-afc7-465aac73c5a7   ::   Confidence:  99.99979
# Identified Person ::  Jerry
# ---
# FacePrintID:  06a86d93-ebbb-4af8-8213-891aa3861acd   ::   Confidence:  99.99979
# Identified Person ::  Jerry
# ---
# FacePrintID:  4bf73450-48a6-482e-a006-7978990289f8   ::   Confidence:  99.99979
# Identified Person ::  Jerry
# ---
# FacePrintID:  585dd312-1bdf-4d6d-8490-73da8aa481c4   ::   Confidence:  99.9999
# Identified Person ::  Jerry
# ---
# FacePrintID:  2f5a2082-fbc2-44ef-837f-09ee1f92eac0   ::   Confidence:  99.9999
# Identified Person ::  Jerry
# ---
# FacePrintID:  438e1262-4a80-425a-bdd1-8682e2d5dfca   ::   Confidence:  99.9997
# Identified Person ::  Jerry
# ---
# ---------------------
# {'Jerry': [99.99979, 99.99979, 99.9996, 99.9997, 99.9996, 99.99979, 99.99979, 99.99979, 99.9999, 99.9999, 99.9997]}
# ---------------------
# Identified Person :  Jerry   ::   Confidence :  99.99976
# ---------------------
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F940AF0>
# ####################################################
# ####################################################
# ---------------------------------------------
# Actual Image of the Person :: Kim
# ---------------------------------------------
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F97DB50>
# FacePrintID:  7790dcb3-fd73-4d12-afa7-3347c1255bf0   ::   Confidence:  99.9997
# Identified Person ::  Kim
# ---
# FacePrintID:  8a9877df-20a5-435c-954f-b3723cb3c5df   ::   Confidence:  99.9997
# Identified Person ::  Kim
# ---
# FacePrintID:  c5c58880-33bd-49cc-b27f-5d8686724cd0   ::   Confidence:  99.9996
# Identified Person ::  Kim
# ---
# FacePrintID:  4999b72e-6bc9-488d-8bde-4695d6514924   ::   Confidence:  99.9995
# Identified Person ::  Kim
# ---
# FacePrintID:  19f302e9-c2eb-4494-b34e-ce8b44660db6   ::   Confidence:  99.9997
# Identified Person ::  Kim
# ---
# FacePrintID:  79b8b224-8bbb-4892-98b4-d34a3aee4c03   ::   Confidence:  99.9995
# Identified Person ::  Kim
# ---
# FacePrintID:  b392d6da-a2d1-4aab-bd0f-4b84b7b158e2   ::   Confidence:  99.9997
# Identified Person ::  Kim
# ---
# FacePrintID:  6dfb3d92-77a3-4d6f-9242-0df9eee4d13b   ::   Confidence:  99.9995
# Identified Person ::  Kim
# ---
# FacePrintID:  467eec98-3ca4-4416-901c-3084c6d9a1c3   ::   Confidence:  99.9997
# Identified Person ::  Kim
# ---
# FacePrintID:  50f2de59-fadf-4eec-97cc-fb1175c5e910   ::   Confidence:  99.9996
# Identified Person ::  Kim
# ---
# FacePrintID:  db8d1c72-480e-4c8d-82e6-f5c013b89c1e   ::   Confidence:  99.9995
# Identified Person ::  Kim
# ---
# ---------------------
# {'Kim': [99.9997, 99.9997, 99.9996, 99.9995, 99.9997, 99.9995, 99.9997, 99.9995, 99.9997, 99.9996, 99.9995]}
# ---------------------
# Identified Person :  Kim   ::   Confidence :  99.99961
# ---------------------
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F97DB50>
# ####################################################
# ####################################################
# ---------------------------------------------
# Actual Image of the Person :: leo
# ---------------------------------------------
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F5BAD90>
# FacePrintID:  5e1722ee-b440-4611-87e1-ec3bf99ade56   ::   Confidence:  99.9995
# Identified Person ::  leo
# ---
# FacePrintID:  00b73c22-8238-4f80-b836-47a8979e19bf   ::   Confidence:  99.9996
# Identified Person ::  leo
# ---
# FacePrintID:  5352be2f-be4f-44f5-ba87-56361b2b2ea5   ::   Confidence:  99.9999
# Identified Person ::  leo
# ---
# FacePrintID:  6a16094a-ebfe-4f08-8f23-183de7158e97   ::   Confidence:  99.99979
# Identified Person ::  leo
# ---
# FacePrintID:  398f8704-0855-4c29-8a05-478fb978492f   ::   Confidence:  99.9996
# Identified Person ::  leo
# ---
# FacePrintID:  c890f91c-4414-4523-8971-c8d3ab709158   ::   Confidence:  99.9999
# Identified Person ::  leo
# ---
# FacePrintID:  7c62f0c5-2ecc-43ae-bd1a-acdf3b854393   ::   Confidence:  99.9996
# Identified Person ::  leo
# ---
# FacePrintID:  447c3e9e-cbdd-4db8-a132-7d44dda6d767   ::   Confidence:  99.9997
# Identified Person ::  leo
# ---
# FacePrintID:  701a1b3d-15b2-4450-9636-2cb942d01f9c   ::   Confidence:  99.9999
# Identified Person ::  leo
# ---
# FacePrintID:  e358e498-cb98-4122-8c38-b764dbaa313c   ::   Confidence:  99.9997
# Identified Person ::  leo
# ---
# ---------------------
# {'leo': [99.9995, 99.9996, 99.9999, 99.99979, 99.9996, 99.9999, 99.9996, 99.9997, 99.9999, 99.9997]}
# ---------------------
# Identified Person :  leo   ::   Confidence :  99.99972
# ---------------------
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F5BAD90>
# ####################################################
# ####################################################
# ---------------------------------------------
# Actual Image of the Person :: Manny
# ---------------------------------------------
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F5BA610>
# FacePrintID:  32b31747-af44-4dd3-9487-c081c10851c9   ::   Confidence:  99.9997
# Identified Person ::  Manny
# ---
# FacePrintID:  e21838c4-b5be-46d9-a237-443266452761   ::   Confidence:  99.9997
# Identified Person ::  Manny
# ---
# FacePrintID:  803c7179-0e10-4229-8d52-f26a561620c8   ::   Confidence:  99.99979
# Identified Person ::  Manny
# ---
# FacePrintID:  7a8a616e-a174-4212-9d8d-835b274a6784   ::   Confidence:  99.99979
# Identified Person ::  Manny
# ---
# FacePrintID:  0e17093a-0345-4ade-b5d3-5100499fe376   ::   Confidence:  99.9996
# Identified Person ::  Manny
# ---
# FacePrintID:  936a39c1-49f0-41aa-ae0c-7b89bbb601cc   ::   Confidence:  99.9997
# Identified Person ::  Manny
# ---
# FacePrintID:  6a874b80-2784-4585-b93e-48e33b8dd2bc   ::   Confidence:  99.9995
# Identified Person ::  Manny
# ---
# FacePrintID:  1862022d-ae3a-4e6b-909e-745be6dd9197   ::   Confidence:  99.9996
# Identified Person ::  Manny
# ---
# FacePrintID:  d61a398f-a803-4439-85a0-eb64d66e2af5   ::   Confidence:  99.9988
# Identified Person ::  Manny
# ---
# FacePrintID:  c09d4bcb-c305-460e-9a1e-dd922367b732   ::   Confidence:  99.9997
# Identified Person ::  Manny
# ---
# FacePrintID:  70c963ce-13ad-424e-817f-dc132296d47a   ::   Confidence:  99.99931
# Identified Person ::  Manny
# ---
# ---------------------
# {'Manny': [99.9997, 99.9997, 99.99979, 99.99979, 99.9996, 99.9997, 99.9995, 99.9996, 99.9988, 99.9997, 99.99931]}
# ---------------------
# Identified Person :  Manny   ::   Confidence :  99.99956
# ---------------------
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F5BA610>
# ####################################################
# ####################################################
# ---------------------------------------------
# Actual Image of the Person :: Ned
# ---------------------------------------------
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F95D400>
# FacePrintID:  bc61e8ac-0e0b-4265-aae1-969cb31994e0   ::   Confidence:  99.9992
# Identified Person ::  Ned
# ---
# FacePrintID:  0180c188-7e12-44b7-b605-2680bb14f16e   ::   Confidence:  99.9995
# Identified Person ::  Ned
# ---
# FacePrintID:  43174a2e-d900-4879-93f0-82addf494135   ::   Confidence:  99.99931
# Identified Person ::  Ned
# ---
# FacePrintID:  3dbee636-bce2-41d2-9a10-f6588faa8d5f   ::   Confidence:  99.9992
# Identified Person ::  Ned
# ---
# FacePrintID:  c0687c83-fae7-442a-873e-9295f6ef3bb0   ::   Confidence:  99.9997
# Identified Person ::  Ned
# ---
# FacePrintID:  a9bd1f70-593e-4248-a882-84bf8ec12f52   ::   Confidence:  99.9992
# Identified Person ::  Ned
# ---
# FacePrintID:  98ab4902-0b2c-4fdf-afed-ac169e241975   ::   Confidence:  99.9996
# Identified Person ::  Ned
# ---
# FacePrintID:  28c77557-4300-41fc-b03e-91cc2f945408   ::   Confidence:  99.9996
# Identified Person ::  Ned
# ---
# FacePrintID:  7d71d6ad-5e30-4f76-b27e-ea8c1c3bec4f   ::   Confidence:  99.9995
# Identified Person ::  Ned
# ---
# FacePrintID:  2bf69dd2-3c9d-4339-8035-2d09566530fa   ::   Confidence:  99.9995
# Identified Person ::  Ned
# ---
# ---------------------
# {'Ned': [99.9992, 99.9995, 99.99931, 99.9992, 99.9997, 99.9992, 99.9996, 99.9996, 99.9995, 99.9995]}
# ---------------------
# Identified Person :  Ned   ::   Confidence :  99.99943
# ---------------------
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F95D400>
# ####################################################
# ####################################################
# ---------------------------------------------
# Actual Image of the Person :: oxam
# ---------------------------------------------
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F7D80D0>
# FacePrintID:  acddc401-e4c8-4019-8bb8-8d0f26cd4307   ::   Confidence:  99.9997
# Identified Person ::  oxam
# ---
# FacePrintID:  978ada2d-41b6-400a-be51-94891a72913b   ::   Confidence:  99.99979
# Identified Person ::  oxam
# ---
# FacePrintID:  475a5aa6-2bcd-4cd5-a893-4c30d878d5a8   ::   Confidence:  99.99979
# Identified Person ::  oxam
# ---
# FacePrintID:  310f12ba-cf73-4a70-8262-da45452d2998   ::   Confidence:  99.99979
# Identified Person ::  oxam
# ---
# FacePrintID:  808d0401-a7c5-4ddc-af0a-c93cfcadd964   ::   Confidence:  99.9999
# Identified Person ::  oxam
# ---
# FacePrintID:  7f274db0-ded5-46a9-a0b5-d87ef86c7c68   ::   Confidence:  99.99979
# Identified Person ::  oxam
# ---
# FacePrintID:  a1c55f4a-3e5d-439a-b3cc-d36d31d17f3b   ::   Confidence:  99.9999
# Identified Person ::  oxam
# ---
# FacePrintID:  bcc87b05-ef39-45a6-a0a7-54f6adc2b8b6   ::   Confidence:  99.9997
# Identified Person ::  oxam
# ---
# FacePrintID:  3cbdfc67-3e03-46c7-9f89-018e4af3f8dd   ::   Confidence:  99.9995
# Identified Person ::  oxam
# ---
# FacePrintID:  65a7d748-525f-4392-97ff-70a76f0c16b8   ::   Confidence:  99.99979
# Identified Person ::  oxam
# ---
# FacePrintID:  ac28e791-e433-49e4-9eb7-b2422547f694   ::   Confidence:  99.99979
# Identified Person ::  oxam
# ---
# ---------------------
# {'oxam': [99.9997, 99.99979, 99.99979, 99.99979, 99.9999, 99.99979, 99.9999, 99.9997, 99.9995, 99.99979, 99.99979]}
# ---------------------
# Identified Person :  oxam   ::   Confidence :  99.99977
# ---------------------
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x243 at 0x2923F7D80D0>
# ####################################################

# %%
image = Image.open("Grouped\group1.jpg")
stream = io.BytesIO()
image.save(stream,format="JPEG")
image_binary = stream.getvalue()

response = rekognition.detect_faces(
    Image={'Bytes':image_binary}                                        
        )
    
all_faces=response['FaceDetails']
    
# Initialize list object
boxes = []

# Get image diameters
image_width = image.size[0]
image_height = image.size[1]
   
# Crop face from image
for face in all_faces:
    box=face['BoundingBox']
    x1 = int(box['Left'] * image_width) * 0.9
    y1 = int(box['Top'] * image_height) * 0.9
    x2 = int(box['Left'] * image_width + box['Width'] * image_width) * 1.10
    y2 = int(box['Top'] * image_height + box['Height']  * image_height) * 1.10
    image_crop = image.crop((x1,y1,x2,y2))
    
    stream = io.BytesIO()
    image_crop.save(stream,format="JPEG")
    image_crop_binary = stream.getvalue()

    # Submit individually cropped image to Amazon Rekognition
    response = rekognition.search_faces_by_image(
            CollectionId='face-matching',
            Image={'Bytes':image_crop_binary}                                       
            )
    
    if len(response['FaceMatches']) > 0:
        # Return results
        print ('Coordinates ', box)
        for match in response['FaceMatches']:
                
            face = dynamodb.get_item(
                TableName='face-matching',               
                Key={'RekognitionId': {'S': match['Face']['FaceId']}}
                )
    
            if 'Item' in face:
                person = face['Item']['FullName']['S']
            else:
                person = 'no match found'
            
            print (match['Face']['FaceId'],match['Face']['Confidence'],person)
# Out:
# Coordinates  {'Width': 0.12533129751682281, 'Height': 0.6637213826179504, 'Left': 0.12116976827383041, 'Top': 0.2408585250377655}
# 65f2f018-71fb-4524-8013-8d8d9acfd6de 99.9999008178711 Alex
# e68acd86-d664-48c7-8567-cfb8ec16178c 99.99979400634766 Alex
# 682690f0-70c5-47aa-b095-136b06a82169 99.99960327148438 Alex
# fa48622f-97bb-4604-b6bc-fb384ba48e30 99.99970245361328 Alex
# 963e0833-4500-410f-b2e7-1cc30eeea6ae 99.99979400634766 Alex
# d5b76127-fcca-400b-a0ab-c19280cf12e1 99.99970245361328 Alex
# 1ae87c03-a6a9-450d-b5ee-ddb289d28934 99.9999008178711 Alex
# 60395350-e93d-4599-99e4-4f3fe76e4360 99.99979400634766 Alex
# 0ab668d2-bf2f-4d86-92f6-07a96f7b5357 99.99979400634766 Alex
# f0913e35-1288-4551-b56b-23fc5f2c2574 99.99979400634766 Alex
# fc8f87f5-c701-464b-8a56-2d075b2e9718 99.99979400634766 Alex
# Coordinates  {'Width': 0.11760370433330536, 'Height': 0.6962652206420898, 'Left': 0.46571895480155945, 'Top': 0.238130122423172}
# 6ca73f3d-5404-465a-8114-c77617014642 99.99949645996094 no match found
# 1bb71f9f-eee2-49ae-97b9-ecb16f6f3033 99.99930572509766 Bob
# dc7ed17b-80a6-4277-8c18-78f4a751cd2c 99.99939727783203 Bob
# 6d18164b-702a-4107-96e4-ac9cb19a4745 99.99949645996094 Bob
# 65927b03-3093-4537-bce4-551b63762416 99.99949645996094 Bob
# 3bdabb0c-70f5-47ae-a6b3-1d8503744caf 99.99960327148438 Bob
# d4876ee5-1160-46c0-b8d8-583076506e75 99.99960327148438 Bob
# 42df2edc-2007-4d2c-9327-3a8ef0e6e4cc 99.99949645996094 Bob
# ea0c2348-c3a7-4133-a70f-793f3c02dd56 99.9999008178711 Bob
# eb175eab-d430-4e56-a61b-1686532384c6 99.99939727783203 Bob
# Coordinates  {'Width': 0.11183454096317291, 'Height': 0.6021581888198853, 'Left': 0.7851781249046326, 'Top': 0.3107793927192688}
# 4c50b1e0-f63f-476c-b5f8-f46f307c2fb3 99.99970245361328 no match found
# c6639b1c-23fb-4aff-a10b-b6887a6c8c7f 99.99970245361328 Charlie
# 6d6c283f-830e-4910-8ad4-0e5cb2ae4ca2 99.99979400634766 Charlie
# 3a299153-0553-488d-81d5-798cebe7e8a6 99.99979400634766 Charlie
# 352fea37-b91d-4edf-b201-dc148f9cfe45 99.99979400634766 Charlie
# c75fe011-31a2-48d0-b95a-564087f14e39 99.9999008178711 Charlie
# 2652d378-abe1-44ed-a1c5-8222acd47642 99.99979400634766 Charlie
# 266b607d-6661-44a1-ac8b-9af0646607b2 99.99970245361328 Charlie
# 9a04a2b4-7110-474d-b213-e26a823e6d98 99.99939727783203 Charlie
# 235147ac-ea8c-49f2-a8ef-6452f81adf37 99.99939727783203 Charlie

# %%
#Copyright 2018 Amazon.com, Inc. or its affiliates. All Rights Reserved.
#PDX-License-Identifier: MIT-0 (For details, see https://github.com/awsdocs/amazon-rekognition-developer-guide/blob/master/LICENSE-SAMPLECODE.)

    # ============== Faces===============
    def StartFaceDetection(self):
        response=self.rek.start_face_detection(Video={'S3Object': {'Bucket': self.bucket, 'Name': self.video}},
            NotificationChannel={'RoleArn': self.roleArn, 'SNSTopicArn': self.snsTopicArn})

        self.startJobId=response['JobId']
        print('Start Job Id: ' + self.startJobId)

    def GetFaceDetectionResults(self):
        maxResults = 10
        paginationToken = ''
        finished = False

        while finished == False:
            response = self.rek.get_face_detection(JobId=self.startJobId,
                                            MaxResults=maxResults,
                                            NextToken=paginationToken)

            print('Codec: ' + response['VideoMetadata']['Codec'])
            print('Duration: ' + str(response['VideoMetadata']['DurationMillis']))
            print('Format: ' + response['VideoMetadata']['Format'])
            print('Frame rate: ' + str(response['VideoMetadata']['FrameRate']))
            print()

            for faceDetection in response['Faces']:
                print('Face: ' + str(faceDetection['Face']))
                print('Confidence: ' + str(faceDetection['Face']['Confidence']))
                print('Timestamp: ' + str(faceDetection['Timestamp']))
                print()

            if 'NextToken' in response:
                paginationToken = response['NextToken']
            else:
                finished = True

# %%
key = 's3://face-recognition-in-videos/video1.mp4'
filename = key.split('/')[-1]

# Create a new transcoding job. Files created by Elastic Transcoder start with 'elastictranscoder/[filename]/[timestamp]_'
timestamp = datetime.datetime.now().strftime('%Y-%m-%d_%H-%M-%S')

client = boto3.client('elastictranscoder')
response = client.create_job(
  PipelineId='1677074649352-hpyshg',
  Input={'Key': key},
  OutputKeyPrefix='elastictranscoder/{}/{}_'.format(filename, timestamp),
  Output={
    'Key': 'transcoded-video.mp4',
    'ThumbnailPattern': 'thumbnail-{count}',
    'PresetId': '1351620000001-000040'
  }
)
